# %%
import pandas as pd
import numpy as np
import string
import re
from sklearn.feature_extraction.text import CountVectorizer

import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen
import re

import nltk
nltk.download('stopwords')

from nltk.util import ngrams
from nltk.stem import WordNetLemmatizer  # lemmatization
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/greenwood/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data = pd.read_csv('metadata.tsv', sep = '\t')
data = data.loc[:,['episode_uri','show_name', 'show_description', 'episode_name', 'episode_description']]
data['docno'] = data.index
data['docno'] = data['docno'].astype(int)
data = data.astype(str)
data.head()
# Out:
#                               episode_uri  \
# 0  spotify:episode:000A9sRBYdVh66csG2qEdj
# 1  spotify:episode:000HP8n3hNIfglT2wSI2cA
# 2  spotify:episode:001UfOruzkA3Bn1SPjcdfa
# 3  spotify:episode:001i89SvIQgDuuyC53hfBm
# 4  spotify:episode:0025RWNwe2lnp6HcnfzwzG
#
#                                            show_name  \
# 0                               Kream in your Koffee
# 1                              Morning Cup Of Murder
# 2  Inside The 18 : A Podcast for Goalkeepers by G...
# 3                                    Arrowhead Live!
# 4                                              FBoL
#
#                                     show_description  \
# 0  A 20-something blunt female takes on the world...
# 1  Ever wonder what murder took place on today in...
# 2  Inside the 18 is your source for all things Go...
# 3  Your favorite podcast for everything @Chiefs! ...
# 4  The comedy podcast about toxic characters, wri...
#
#                                         episode_name  \
# 0                            1: It’s Christmas Time!
# 1  The Goleta Postal Facility shootings- January ...
# 2  Ep.36 - Incorporating a Singular Goalkeeping C...
# 3                   Episode 1: Arrowhead Live! Debut
# 4  The Lion, The Witch, And The Wardrobe - Ashley...
#
#                                  episode_description docno
# 0  On the first ever episode of Kream in your Kof...     0
# 1  See something, say something. It’s a mantra ma...     1
# 2  Today’s episode is a sit down Michael and Omar...     2
# 3  Join us as we take a look at all current Chief...     3
# 4  The modern morality tail of how to stay good f...     4

# %%
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

# pre-processing
def pre_process(text):
    punctuation_marks = string.punctuation.replace("'", "")

    # separate punctuation from words - preserving apostrophe
    if preprocessing_switches['separate_out_punctuation']:
        for c in punctuation_marks:
            text = text.replace(c, ' ' + c + ' ')

    #converting numbers to digits
    if preprocessing_switches["convert_number_words_to_digits"]:
        text = text2int(text)   

    #removing numbers
    if preprocessing_switches["convert_numbers"]:
        text = re.sub('\d+', 'NUMBER',text)
        text = text.replace('NUMBER ', '')

        #converts to lower case
    if preprocessing_switches['convert_to_lowercase']:    
        text = text.lower()

    # Tokenize the text
    tokens = text.split()

    # Remove stopwords
    if preprocessing_switches['separate_out_punctuation']:    
        stop_words = set(stopwords.words("english"))
        tokens = [token for token in tokens if token not in stop_words]

    # Remove punctuation
    if preprocessing_switches['remove_punctuation']:    
        tokens = [token for token in tokens if token not in punctuation_marks]

    # Lemmatize the tokens
    if preprocessing_switches['apply_lemmatization']:
        tokens = [lemmatizer.lemmatize(token) for token in tokens]

    # Stem the tokens
    if preprocessing_switches['stem_tokens']:
        tokens = [stemmer.stem(token) for token in tokens]
            

    return ' '.join(tokens)

# %%
preprocessing_switches = {'convert_to_lowercase': True,
                            'separate_out_punctuation': True,
                            'remove_punctuation': True,
                            'convert_number_words_to_digits': True,
                            'convert_numbers': True,
                            'remove_stopwords': True,
                            'apply_lemmatization': False,
                            'stem_tokens': False}

# %%
def text2int(textnum, numwords={}):
    if not numwords:
        units = [
        "zero", "one", "two", "three", "four", "five", "six", "seven", "eight",
        "nine", "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen",
        "sixteen", "seventeen", "eighteen", "nineteen",
        ]

        tens = ["", "", "twenty", "thirty", "forty", "fifty", "sixty", "seventy", "eighty", "ninety"]

        scales = ["hundred", "thousand", "million", "billion", "trillion"]

        numwords["and"] = (1, 0)
        for idx, word in enumerate(units):  numwords[word] = (1, idx)
        for idx, word in enumerate(tens):       numwords[word] = (1, idx * 10)
        for idx, word in enumerate(scales): numwords[word] = (10 ** (idx * 3 or 2), 0)

    ordinal_words = {'first':1, 'second':2, 'third':3, 'fifth':5, 'eighth':8, 'ninth':9, 'twelfth':12}
    ordinal_endings = [('ieth', 'y'), ('th', '')]

    textnum = textnum.replace('-', ' ')

    current = result = 0
    curstring = ""
    onnumber = False
    for word in textnum.split():
        if word in ordinal_words:
            scale, increment = (1, ordinal_words[word])
            current = current * scale + increment
            if scale > 100:
                result += current
                current = 0
            onnumber = True
        else:
            for ending, replacement in ordinal_endings:
                if word.endswith(ending):
                    word = "%s%s" % (word[:-len(ending)], replacement)

            if word not in numwords:
                if onnumber:
                    curstring += repr(result + current) + " "
                curstring += word + " "
                result = current = 0
                onnumber = False
            else:
                scale, increment = numwords[word]

                current = current * scale + increment
                if scale > 100:
                    result += current
                    current = 0
                onnumber = True

    if onnumber:
        curstring += repr(result + current)

    return curstring

# %%
#create subset for processing and apply pre-processing
data_subset = data.loc[:10000]

data_processed = data_subset['show_description'].apply(pre_process).to_list()

# %%
vectorizer = CountVectorizer()
documents_vectorized = vectorizer.fit_transform(data_processed)
vocabulary = vectorizer.get_feature_names_out()

# %%
dataframe = pd.DataFrame(documents_vectorized.toarray(), columns=vocabulary)

# removing low word counts to improve performance - low word counts also not likely to be relevant
word_counts = dataframe.sum(axis=0)
to_remove = word_counts[word_counts <4].index
dataframe = dataframe.drop(columns = to_remove)
dataframe.shape
# Out:
# (10001, 7979)

# %%
#term frequencies
dfs = (dataframe > 0).sum(axis=0)
#idfs
N = dataframe.shape[0]
idfs = np.log10(N/dfs)
#BM25
k_1 = 1.2
b = 0.8

# The following line of code considers all words in each document:
dls_all = [len(d.split(' ')) for d in data_processed] # vector

# But we're not intrested in stop words, therefore, let's do the following: 
dls = dataframe.sum(axis=1).tolist()  # document lengths in words
avgdl = np.mean(dls) # avarage document length

numerator = np.array((k_1 + 1) * dataframe)
denominator = np.array(k_1 *((1 - b) + b * (dls / avgdl))).reshape(N, 1) + \
                       np.array(dataframe)

BM25_tf = numerator / denominator

idfs = np.array(idfs)  # inverse document frequencies

BM25_score = idfs * BM25_tf

# %%
bm25_idf = pd.DataFrame(BM25_score, columns=dataframe.columns)
bm25_idf['christmas'].sort_values(ascending = False)
# Out:
# 7392     4.807133
# 2077     3.859928
# 6765     3.859928
# 9530     3.859928
# 2084     3.659442
#            ...
# 3335     0.000000
# 3336     0.000000
# 3337     0.000000
# 3338     0.000000
# 10000    0.000000
# Name: christmas, Length: 10001, dtype: float64

# %%
data.loc[7392]
# Out:
# episode_uri                       spotify:episode:0XgrKcGfkaf3cwGxkwKe5e
# show_name                                           61 Days of Christmas
# show_description       Hosts Abby and Kelsy watch the 40 new Hallmark...
# episode_name             Christmas Wishes & Mistletoe Kisses Snoozefest
# episode_description    Hosts Abby and Kelsy recount the exhausting fi...
# docno                                                               7392
# Name: 7392, dtype: object

# %%
query = 'christmas'
columns = ['show_name', 'show_description']

query_words = pre_process(query).split(' ')
top_results = bm25_idf[query_words].sum(axis = 1).sort_values(ascending = False).index[:5].tolist()
data.loc[top_results, columns]
# Out:
#                                        show_name  \
# 7392                        61 Days of Christmas
# 2077  A Cup Of Cheer: A Seasonal Holiday Podcast
# 6765  A Cup Of Cheer: A Seasonal Holiday Podcast
# 9530  A Cup Of Cheer: A Seasonal Holiday Podcast
# 2084                             MC Crue Podcast
#
#                                        show_description
# 7392  Hosts Abby and Kelsy watch the 40 new Hallmark...
# 2077  We don’t know if there will be snow, so have a...
# 6765  We don’t know if there will be snow, so have a...
# 9530  We don’t know if there will be snow, so have a...
# 2084  On this podcast, we'll be talking about anythi...

# %%
# from sqlalchemy import create_engine
# engine = create_engine('sqlite:///IRDB', echo=False)
# bm25_idf.to_sql('users', con=engine)

(bm25_idf.memory_usage(deep = True).sum()) / (1024 * 1024)
# bm25_idf.to_csv('Web Page/BM25_data.csv')
# Out:
# 608.8103866577148

# %%
data.loc[2084, 'show_description']
# Out:
# "On this podcast, we'll be talking about anything and everything, especially what makes a movie a Christmas movie!   You can follow the guys on Instagram @mc.crue.podcast or e-mail us segment ideas at mccruepod@gmail.com  Cheers! "

# %% [markdown]
# <div style="background-color: #090e60; padding: 10px; border: 8px solid  white;">
#     <p style="text-align: center; font-weight: bold; color: white; font-size: 30px; margin: 0; position: relative; top: 50%; transform: translateY(-50%); font-family: 'Italianno', cursive;">&ndash;&ndash;&ndash;&nbsp;Queries&nbsp;&ndash;&ndash;&ndash;
#     </p>
# </div>

# %%
urls = [
    "https://trecpodcasts.github.io/resources/podcasts_2020_topics_train.xml",
    "https://trecpodcasts.github.io/resources/podcasts_2020_topics_test.xml"
]

tables = []
for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "xml")
    rows = soup.find_all("topic")

    # Create dict with column headings and empty lists
    table_dict = {"num": [], "query": [], "type": [], "description": []}

    # For every row in the table, find each cell element and add it to the list
    for row in rows:
        table_dict = {
            col: table_dict[col] + [row.find(col).text] for col in table_dict
        }

    table = pd.DataFrame(table_dict)
    table = table.applymap(lambda x: x[0] if isinstance(x, list) else x)
    tables.append(table)

query = pd.concat(tables, ignore_index=True)
query.head()
# Out:
#   num                          query        type  \
# 0   1             coronavirus spread     topical
# 1   2  greta thunberg cross atlantic     topical
# 2   3               black hole image     topical
# 3   4      story about riding a bird   refinding
# 4   5            daniel ek interview  known item
#
#                                          description
# 0  What were people saying about the spread of th...
# 1  What were people saying about Greta Thunberg’s...
# 2  In May 2019 astronomers released the first-eve...
# 3  I remember hearing a podcast that had a story ...
# 4  Someone told me about a podcast interview with...

# %%
query = query[~query['num'].isin(['47', '50'])].reset_index(drop=True)
query.head()
# Out:
#   num                          query        type  \
# 0   1             coronavirus spread     topical
# 1   2  greta thunberg cross atlantic     topical
# 2   3               black hole image     topical
# 3   4      story about riding a bird   refinding
# 4   5            daniel ek interview  known item
#
#                                          description
# 0  What were people saying about the spread of th...
# 1  What were people saying about Greta Thunberg’s...
# 2  In May 2019 astronomers released the first-eve...
# 3  I remember hearing a podcast that had a story ...
# 4  Someone told me about a podcast interview with...

# %%
pd.options.display.max_colwidth = 200
short_query = query.loc[:, ['num', 'query']].rename(columns={'num': 'qid','query': 'query'})
full_query = query.loc[:, ['num', 'description']].rename(columns={'num': 'qid','description': 'query'})

# %%
def remove_non_alphanumeric(row):
    return re.sub(r'[^a-zA-Z0-9 ]+', '', row.query)

full_query['query'] = full_query.apply(remove_non_alphanumeric, axis=1)
full_query.head()
# Out:
#   qid  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                                                                                                                      query
# 0                                                                                                     What were people saying about the spread of the novel coronavirus NCOV19 in Wuhan at the end of 2019
# 1                                                   What were people saying about Greta Thunbergs sailing trip across the Atlantic Ocean in the fall of 2019 and its relationship to global climate change
# 2  In May 2019 astronomers released the firstever picture of a black hole I would like to hear some conversations and educational discussion about the science of astronomy black holes and of the pict...
# 3                                                                                               I remember hearing a podcast that had a story about a kid riding some kind of bird I want to find it again
# 4  Someone told me about a podcast interview with Daniel Ek CEO of Spotify about the founding and early days of Spotify I would like to find the show and episode that contains that interview Other in...

# %% [markdown]
# <div style="background-color: #090e60; padding: 10px; border: 8px solid  white;">
#     <p style="text-align: center; font-weight: bold; color: white; font-size: 30px; margin: 0; position: relative; top: 50%; transform: translateY(-50%); font-family: 'Italianno', cursive;">&ndash;&ndash;&ndash;&nbsp;Qrels&nbsp;&ndash;&ndash;&ndash;
#     </p>
# </div>

# %% [markdown]
# The Relevance assessments (“qrels”) 2021 test set in not available so the 2020 test set has been used to perform it.

# %%
url_train = "https://trecpodcasts.github.io/resources/2020_train_qrels.list"
url_test ="https://trecpodcasts.github.io/resources/2020_test_qrels.list"

# %%
response = requests.get(url_train)
lines = response.text.split("\n")

data_qrel = []
for line in lines:
    if line:
        query, _, episode_uri, relevance = line.split("\t")
        data_qrel.append({"query": query, "episode_uri": episode_uri, "relevance": relevance})

qrel = pd.DataFrame(data_qrel)
qrel.shape
# Out:
# (609, 3)

# %%
# add Podcast Track 2020 test set QRels
url_test = "https://trecpodcasts.github.io/resources/2020_test_qrels.list"
response_test = requests.get(url_test)

lines_test = response_test.text.split("\n")
data_test = []
for line in lines_test:
    if line:
        query, _, episode_uri, relevance = line.split()
        data_test.append({"query": query, "episode_uri": episode_uri, "relevance": relevance})

qrel_test = pd.DataFrame(data_test)
# qrel = qrel.append(qrel_test).reset_index(drop=True)
qrel = pd.concat((qrel, qrel_test)).reset_index(drop=True)
qrel.shape
# Out:
# (10035, 3)

# %%
qrel
# Out:
#       query                                    episode_uri relevance
# 0         1   spotify:episode:0E2nqCXMkS218SE72APmNr_240.0         2
# 1         1   spotify:episode:0E2nqCXMkS218SE72APmNr_300.0         2
# 2         1   spotify:episode:0E2nqCXMkS218SE72APmNr_360.0         2
# 3         1   spotify:episode:0Th494DvnO5dU8vTi3QHm2_120.0         1
# 4         1  spotify:episode:199bOiXL0l4YsRaSNDNXvP_1200.0         2
# ...     ...                                            ...       ...
# 10030    32   spotify:episode:7lrWzeepJQwhr0jyuVEk9m_300.0         0
# 10031    32   spotify:episode:7lrWzeepJQwhr0jyuVEk9m_600.0         0
# 10032    32   spotify:episode:7ok6wB1WviyXvxba0wdb5q_720.0         0
# 10033    32   spotify:episode:7ok6wB1WviyXvxba0wdb5q_780.0         0
# 10034    32   spotify:episode:7pRpADlrOriqKmWPR6CD3v_420.0         0
#
# [10035 rows x 3 columns]

# %%
qrel['episode_uri'] = qrel['episode_uri'].apply(lambda uri: uri.split('_')[0])
qrel = qrel.groupby(['query', 'episode_uri']).max().reset_index()
qrel
# Out:
#      query                             episode_uri relevance
# 0        1  spotify:episode:0E2nqCXMkS218SE72APmNr         2
# 1        1  spotify:episode:0Th494DvnO5dU8vTi3QHm2         1
# 2        1  spotify:episode:199bOiXL0l4YsRaSNDNXvP         2
# 3        1  spotify:episode:1ZA1QTtylexrVt75xiprNH         2
# 4        1  spotify:episode:1o0HCHjNtRWdEWRTWJhzyC         0
# ...    ...                                     ...       ...
# 5825     9  spotify:episode:6v0auT8BbeXzMTmg9FjyDB         1
# 5826     9  spotify:episode:7EKJswck8jP4tXWHXVJCdO         0
# 5827     9  spotify:episode:7N0z3FpvsWWTCSgARuCd8C         0
# 5828     9  spotify:episode:7mIga7ujiMVbbEN5bBQPUX         0
# 5829     9  spotify:episode:7mh26AlQ7FEKg9Gj0Eq2mz         0
#
# [5830 rows x 3 columns]

# %%
# Find all episodes present in qrels
in_qrels = data.loc[data['episode_uri'].isin(qrel['episode_uri'].unique())]

# Check for NaN and empty string entries
null_or_empty = in_qrels[in_qrels['episode_description'].isna() | (in_qrels['episode_description'] == '')]

# Check for one-word descriptions
def one_word(row):
    return re.search(r'.*\s', row.episode_description)

one_word_descr = list(in_qrels.index[in_qrels.apply(one_word, axis=1).isna()])
one_word_descr
# Out:
# [3972, 101227]

# %%
# Find all episodes present in qrels
qrel_uris = set(qrel['episode_uri'].unique())
in_qrels = data[data['episode_uri'].isin(qrel_uris)]

# Check for NaN and empty string entries
null_or_empty = in_qrels[in_qrels['episode_description'].isna() | (in_qrels['episode_description'] == '')]

# Check for one-word descriptions
one_word_descr = in_qrels[in_qrels['episode_description'].str.count(' ') == 0]

# Remove QRels with one-word episode descriptions
qrel = qrel[~qrel['episode_uri'].isin(one_word_descr['episode_uri'])].reset_index(drop=True)

# Find indices of NaN and empty string entries
null_idxs = in_qrels[in_qrels['episode_description'].isna()].index
empty_idxs = in_qrels[in_qrels['episode_description'] == ''].index

# Check for one-word descriptions using a lambda function
one_word_descr = in_qrels[in_qrels.apply(lambda x: len(x['episode_description'].split()) == 1, axis=1)]
one_word_descr.shape
# Out:
# (19, 6)

# %%
# Remove QRels with one-word episode descriptions using boolean indexing
qrel = qrel[~qrel['episode_uri'].isin(one_word_descr['episode_uri'])].reset_index(drop=True)
qrel.shape
# Out:
# (5738, 3)

# %%
# create dict {episode_uri: doc}
docno_dict = dict(data[['episode_uri', 'docno']].values)

# insert docno for each episode_uri in qrels using dict
qrel['docno'] = qrel['episode_uri'].map(docno_dict)

# rename columns and change data types to make qrels compatible with PyTerrier
qrel = qrel.rename(columns={'query': 'qid', 'relevance': 'label'})
qrel['qid'] = qrel['qid'].astype(str)
qrel['label'] = qrel['label'].astype(int)  # Convert the 'label' column to integers
qrel = qrel[['qid', 'docno', 'label']]

# display qrels
qrel
# Out:
#      qid   docno  label
# 0      1    3096      2
# 1      1    6496      1
# 2      1   15551      2
# 3      1   21291      2
# 4      1   24523      0
# ...   ..     ...    ...
# 5733   9   93648      1
# 5734   9   97871      0
# 5735   9   99768      0
# 5736   9  102459      0
# 5737   9  102562      0
#
# [5738 rows x 3 columns]

# %% [markdown]
# <div style="background-color: #090e60; padding: 10px; border: 8px solid  white;">
#     <p style="text-align: center; font-weight: bold; color: white; font-size: 30px; margin: 0; position: relative; top: 50%; transform: translateY(-50%); font-family: 'Italianno', cursive;">&ndash;&ndash;&ndash;&nbsp;Data&nbsp;&ndash;&ndash;&ndash;
#     </p>
# </div>

# %%
data.head()
# Out:
#                               episode_uri  \
# 0  spotify:episode:000A9sRBYdVh66csG2qEdj
# 1  spotify:episode:000HP8n3hNIfglT2wSI2cA
# 2  spotify:episode:001UfOruzkA3Bn1SPjcdfa
# 3  spotify:episode:001i89SvIQgDuuyC53hfBm
# 4  spotify:episode:0025RWNwe2lnp6HcnfzwzG
#
#                                                   show_name  \
# 0                                      Kream in your Koffee
# 1                                     Morning Cup Of Murder
# 2  Inside The 18 : A Podcast for Goalkeepers by Goalkeepers
# 3                                           Arrowhead Live!
# 4                                                     FBoL
#
#                                                                                                                                                                                           show_description  \
# 0                         A 20-something blunt female takes on the world and gives you her take on it. Enjoy visits from special guests and friends to give insight and input into interesting situations.
# 1  Ever wonder what murder took place on today in true crime history? If so, sit back and grab a cup of coffee as you enjoy your daily dose of TC goodness. Your host, Korina Biemesderfer, guides you ...
# 2  Inside the 18 is your source for all things Goalkeeping! Each week we are joined by guests from around the world. We recap the weeks events, discuss new training techniques and have candid convers...
# 3                                             Your favorite podcast for everything @Chiefs! Providing #ChiefsKingdom with up to the minute news & insight all day, everyday with @KC_Winn & @grant_morse7🎙
# 4  The comedy podcast about toxic characters, writers, and tropes of literature, folklore, myths, and legend.   Join host Emily Edwards to discuss feminist literature, toxic masculinity, gender roles...
#
#                                                                                          episode_name  \
# 0                                                                             1: It’s Christmas Time!
# 1                 The Goleta Postal Facility shootings- January 30 2020 - Today in True Crime History
# 2  Ep.36 - Incorporating a Singular Goalkeeping Curriculum in the United States w/ guest Phil Wheddon
# 3                                                                    Episode 1: Arrowhead Live! Debut
# 4                                               The Lion, The Witch, And The Wardrobe - Ashley Beall
#
#                                                                                                                                                                                        episode_description  \
# 0          On the first ever episode of Kream in your Koffee, Katie talks about tips for Christmas shopping. We also get a little insight into who and what we’ll be hearing about in next weeks episode!
# 1  See something, say something. It’s a mantra many live by. If you see something strange, call it in or make someone aware, even if it seems innocuous. Jennifer San Marco had strange behaviors. It w...
# 2  Today’s episode is a sit down Michael and Omar had with former USMNT and former USWNT goalkeeper coach, Phil Wheddon. Phil discusses how he started the International Goalkeeper Coaches Conference ...
# 3  Join us as we take a look at all current Chiefs news, including the draft, free agency, in-house contract talks, and much more!  ---   This episode is sponsored by  · Anchor: The easiest way to ma...
# 4  The modern morality tail of how to stay good for Christmas. Ashley Beall of Make It Modern Podcast (@MIM_Podcast) joins me to discuss the redemption arcs of one of KidLit's biggest fuckbois, Edmun...
#
#   docno
# 0     0
# 1     1
# 2     2
# 3     3
# 4     4

# %%
short_query.head()
# Out:
#   qid                          query
# 0   1             coronavirus spread
# 1   2  greta thunberg cross atlantic
# 2   3               black hole image
# 3   4      story about riding a bird
# 4   5            daniel ek interview

# %%
full_query.head()
# Out:
#   qid  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                                                                                                                      query
# 0                                                                                                     What were people saying about the spread of the novel coronavirus NCOV19 in Wuhan at the end of 2019
# 1                                                   What were people saying about Greta Thunbergs sailing trip across the Atlantic Ocean in the fall of 2019 and its relationship to global climate change
# 2  In May 2019 astronomers released the firstever picture of a black hole I would like to hear some conversations and educational discussion about the science of astronomy black holes and of the pict...
# 3                                                                                               I remember hearing a podcast that had a story about a kid riding some kind of bird I want to find it again
# 4  Someone told me about a podcast interview with Daniel Ek CEO of Spotify about the founding and early days of Spotify I would like to find the show and episode that contains that interview Other in...

# %%
qrel.head()
# Out:
#   qid  docno  label
# 0   1   3096      2
# 1   1   6496      1
# 2   1  15551      2
# 3   1  21291      2
# 4   1  24523      0

# %% [markdown]
# <div style="background-color: #090e60; padding: 10px; border: 8px solid  white;">
#     <p style="text-align: center; font-weight: bold; color: white; font-size: 30px; margin: 0; position: relative; top: 50%; transform: translateY(-50%); font-family: 'Italianno', cursive;">&ndash;&ndash;&ndash;&nbsp;Query Testing and PyTerrier&nbsp;&ndash;&ndash;&ndash;
#     </p>
# </div>

# %%
import os
# os.environ["JAVA_HOME"] = "/Library/Java/JavaVirtualMachines/jdk-20.jdk/Contents/Home"
import pyterrier as pt
import numpy as np
import pandas as pd
if not pt.started():
    pt.init()
   

# data = pd.read_csv('metadata.tsv', sep = '\t')
# Out:
# terrier-assemblies 5.8 jar-with-dependencies not found, downloading to /Users/greenwood/.pyterrier...
# Done
# terrier-python-helper 0.0.8 jar not found, downloading to /Users/greenwood/.pyterrier...
# Done
# PyTerrier 0.10.0 has loaded Terrier 5.8 (built by craigm on 2023-11-01 18:05) and terrier-helper 0.0.8

# %%
#removing na vals as create issue with preprocessing
processed_data = data[data['episode_description'].notna()] 
# data.reset_index(drop = True, inplace = True)
#pre process
processed_data['episode_description'] = processed_data['episode_description'].apply(pre_process)

# data =  data.loc[:10000]
processed_data.head()
# Out:
#                               episode_uri  \
# 0  spotify:episode:000A9sRBYdVh66csG2qEdj
# 1  spotify:episode:000HP8n3hNIfglT2wSI2cA
# 2  spotify:episode:001UfOruzkA3Bn1SPjcdfa
# 3  spotify:episode:001i89SvIQgDuuyC53hfBm
# 4  spotify:episode:0025RWNwe2lnp6HcnfzwzG
#
#                                                   show_name  \
# 0                                      Kream in your Koffee
# 1                                     Morning Cup Of Murder
# 2  Inside The 18 : A Podcast for Goalkeepers by Goalkeepers
# 3                                           Arrowhead Live!
# 4                                                     FBoL
#
#                                                                                                                                                                                           show_description  \
# 0                         A 20-something blunt female takes on the world and gives you her take on it. Enjoy visits from special guests and friends to give insight and input into interesting situations.
# 1  Ever wonder what murder took place on today in true crime history? If so, sit back and grab a cup of coffee as you enjoy your daily dose of TC goodness. Your host, Korina Biemesderfer, guides you ...
# 2  Inside the 18 is your source for all things Goalkeeping! Each week we are joined by guests from around the world. We recap the weeks events, discuss new training techniques and have candid convers...
# 3                                             Your favorite podcast for everything @Chiefs! Providing #ChiefsKingdom with up to the minute news & insight all day, everyday with @KC_Winn & @grant_morse7🎙
# 4  The comedy podcast about toxic characters, writers, and tropes of literature, folklore, myths, and legend.   Join host Emily Edwards to discuss feminist literature, toxic masculinity, gender roles...
#
#                                                                                          episode_name  \
# 0                                                                             1: It’s Christmas Time!
# 1                 The Goleta Postal Facility shootings- January 30 2020 - Today in True Crime History
# 2  Ep.36 - Incorporating a Singular Goalkeeping Curriculum in the United States w/ guest Phil Wheddon
# 3                                                                    Episode 1: Arrowhead Live! Debut
# 4                                               The Lion, The Witch, And The Wardrobe - Ashley Beall
#
#                                                                                                                                                                                        episode_description  \
# 0                                                                                   ever episode kream koffee katie talks tips christmas shopping also get little insight we’ll hearing next weeks episode
# 1  see something say something it’s mantra many live see something strange call make someone aware even seems innocuous jennifer san marco strange behaviors clear many woman suffered mental illness u...
# 2  today’s episode sit michael omar wi former usmnt former uswnt goalkeeper coach phil wheddon phil discusses started international goalkeeper coaches conference igcc us needs order create successful...
# 3                                      join us take look current chiefs news including draft free agency house contract talks much episode sponsored · anchor easiest way make podcast https anchor fm app
# 4  modern morality tail stay good christmas ashley beall make modern podcast mim podcast joins discuss redemption arcs kidlit's biggest fuckbois edmund pevensie itunes spotify youtube stitcher google...
#
#   docno
# 0     0
# 1     1
# 2     2
# 3     3
# 4     4

# %%
# !rm -rf ./WebPage/pd_index

#creating a document dictionary to be indexed and stored by pyterrier
docs = processed_data[['docno', 'episode_description']]
docs = docs.rename(columns = {'episode_description': 'text'})
docs = docs.to_dict(orient="records")

pd_indexer = pt.IterDictIndexer("./WebPage/pd_index")
index = pd_indexer.index(docs)
# Out:
# 23:36:12.791 [ForkJoinPool-1-worker-3] WARN org.terrier.structures.indexing.Indexer - Adding an empty document to the index (5) - further warnings are suppressed
# 23:36:37.384 [ForkJoinPool-1-worker-3] WARN org.terrier.structures.indexing.Indexer - Indexed 293 empty documents

# %%
#below details the info contained in the indexed data
index_file = pt.IndexFactory.of(index)
print(index_file.getCollectionStatistics(), index_file.getMetaIndex())
# Out:
# Number of documents: 105360
# Number of terms: 126902
# Number of postings: 3917860
# Number of fields: 1
# Number of tokens: 5211888
# Field names: [text]
# Positions:   false
#  <org.terrier.structures.MetaIndex at 0x7fd6a6341680 jclass=org/terrier/structures/MetaIndex jself=<LocalRef obj=0x7fd772eced30 at 0x7fd6a509f470>>

# %%
def get_example_index(docid, index_file):
    di = index_file.getDirectIndex()
    doi = index_file.getDocumentIndex()
    lex = index_file.getLexicon()
    example_index = pd.DataFrame(columns=['Term', 'Frequency'])
    
    for posting in di.getPostings(doi.getDocumentEntry(docid)):
        termid = posting.getId()
        lee = lex.getLexiconEntry(termid)
        term_freq = pd.DataFrame([[str(lee.getKey()), str(posting.getFrequency())]], columns=['Term', 'Frequency'])
        example_index = pd.concat([example_index, term_freq])
#         example_index = example_index.append(term_freq)

    example_index = example_index.reset_index(drop=True)
    return example_index

# %%
def print_episode_info(docid, metadf):
    show_name = metadf.loc[metadf.docno == str(docid)].show_name.values[0]
    episode_name = metadf.loc[metadf.docno == str(docid)].episode_name.values[0]
    episode_description = metadf.loc[metadf.docno == str(docid)].episode_description.values[0]
    
    print(f'show name: {show_name}')
    print(f'episode name: {episode_name}')
    print(f'episode description: {episode_description}')

# %%
docid = 6
example_index = get_example_index(docid, index_file)
print_episode_info(docid, data)

example_index.head()
# Out:
# show name: The Feminization Boudoir
# episode name: The Sissy's Mentor (Part 5)
# episode description: Miss Jenn Davis reads the final part of The Sissy's Mentor.  It's the story of a young inexperienced college freshman and the dominant woman who takes him under her wing or is that wig?   You can find a lot more great erotic content from Jenn at MissJennDavis.com. Remember that this podcast plays clips (Usually 40%-50%) from audios.  At least half the show is missing and in that half are the very sexiest parts. Please support Candy Apple Press at our clipsites: IWantClips Clips4Sale and buy our books: Amazon.com You can also donate to the Podcast directly at Anchor.fm.  Wherever you listen, please give us good feedback. Thanks, Kylie  ---   This episode is sponsored by  · Anchor: The easiest way to make a podcast.  https://anchor.fm/app  Support this podcast: https://anchor.fm/kylie-gable/support
#       Term Frequency
# 0   episod         1
# 1       fm         3
# 2     http         2
# 3     show         1
# 4  support         3

# %%
bm25 = pt.BatchRetrieve(index, wmodel='BM25')
pl2 = pt.BatchRetrieve(index, wmodel='PL2')
lgd = pt.BatchRetrieve(index, wmodel='LGD')
dfrbm25 = pt.BatchRetrieve(index, wmodel='DFR_BM25')
dfreeklim = pt.BatchRetrieve(index, wmodel='DFReeKLIM')
bm25f = pt.BatchRetrieve(index, wmodel='BM25F')

model_dict = {'BM25': bm25,
              'PL2': pl2,
              'LGD': lgd,
              'DFRMB25' : dfrbm25,
              'DFREEKLIM' : dfreeklim,
              'BM25F': bm25f}

# %%
eval_metrics_list =['map', 'ndcg', 'recip_rank', 'mrt', 'recall']

exp_df_short = pt.Experiment(
    list(model_dict.values()),
    short_query,
    qrel,
    eval_metrics=eval_metrics_list,
    names=list(model_dict.keys())
)
exp_df_short.sort_values(by=['map'], ascending=False)[:5]
# Out:
# 23:36:48.129 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.134 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.207 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.212 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.217 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.221 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.323 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.327 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.331 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.455 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.459 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.463 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.905 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.910 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:48.915 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:49.135 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:49.140 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:49.225 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:49.228 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:49.277 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:49.282 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:49.286 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:49.796 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:49.801 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:49.806 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:49.810 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.055 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.060 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.064 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.155 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.160 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.226 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.230 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.235 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.367 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.370 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.374 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.462 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.467 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.471 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:50.730 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:52.589 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:52.596 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:52.601 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:52.709 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:52.713 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.262 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.268 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.412 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.420 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.476 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.483 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.576 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.580 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.612 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.618 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.622 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.758 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.762 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.767 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.771 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.841 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.847 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:53.852 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:54.314 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:54.319 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:54.362 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:54.369 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:54.374 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:54.377 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:54.927 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:54.930 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.048 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.055 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.167 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.199 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.210 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.218 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.453 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.457 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.464 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.768 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.774 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.779 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.929 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.935 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:55.940 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:56.768 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:56.774 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:56.783 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:57.557 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:57.562 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:57.637 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:57.642 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:57.763 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:57.768 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:57.858 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:57.863 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:57.868 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.292 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.297 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.344 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.349 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.359 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.486 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.490 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.577 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.582 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.588 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.626 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.632 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.637 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.937 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.941 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:58.946 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.167 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.171 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.177 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.294 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.299 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.303 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.308 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.493 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.498 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.506 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.643 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.648 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.655 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.764 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.769 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.979 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.984 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:36:59.989 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:00.346 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:00.351 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:00.357 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:00.470 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:00.475 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:00.503 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:00.513 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:00.521 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:00.524 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:00.529 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
#         name       map      ndcg  recip_rank       R@5      R@10      R@15  \
# 4  DFREEKLIM  0.141072  0.297669    0.531197  0.137423  0.168209  0.188210
# 2        LGD  0.133783  0.289684    0.487998  0.134447  0.168885  0.190978
# 3    DFRMB25  0.122409  0.280917    0.494525  0.125483  0.159352  0.177495
# 1        PL2  0.121682  0.278848    0.490628  0.127044  0.150412  0.172392
# 0       BM25  0.121576  0.279072    0.484478  0.127453  0.160993  0.172634
#
#        R@20      R@30     R@100     R@200     R@500    R@1000        mrt
# 4  0.200608  0.220437  0.295078  0.326691  0.361446  0.388210  27.880569
# 2  0.199485  0.224030  0.288673  0.328579  0.365176  0.384339  27.682035
# 3  0.189535  0.206277  0.282169  0.319773  0.353880  0.373435  26.759914
# 1  0.179501  0.194108  0.276917  0.318328  0.351284  0.374561  33.883234
# 0  0.187243  0.207548  0.280680  0.319302  0.353728  0.372989  45.600431

# %%
exp_df_short = pt.Experiment(
    list(model_dict.values()),
    full_query,
    qrel,
    eval_metrics=eval_metrics_list,
    names=list(model_dict.keys())
)

exp_df_short.sort_values(by=['map'], ascending=False)[:5]
# Out:
# 23:37:17.285 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.289 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.294 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.299 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.306 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.310 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.314 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.816 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.819 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.822 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.826 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.829 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.833 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.837 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.842 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.845 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.850 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.923 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.927 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.930 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:17.934 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.658 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.662 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.667 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.670 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.674 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.677 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.680 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.703 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.709 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.712 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.716 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.719 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.722 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:18.827 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:20.074 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:20.077 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:20.081 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:20.084 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:20.088 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:20.093 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:20.098 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:20.102 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:20.105 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:20.108 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.296 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.304 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.309 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.314 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.318 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.321 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.327 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.330 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.333 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.337 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.341 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.446 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.452 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.457 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.461 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.466 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.471 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:22.574 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:25.436 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:25.441 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:25.456 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:25.463 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:25.472 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:25.481 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:25.487 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:25.492 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:25.502 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.134 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.139 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.148 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.157 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.165 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.172 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.177 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.196 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.204 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.212 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.218 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.223 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.228 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.359 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.367 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.375 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.382 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.392 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.490 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.497 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.509 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:26.518 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.738 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.741 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.747 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.751 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.756 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.761 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.766 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.788 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.792 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.798 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.804 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.809 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.814 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.934 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.939 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.944 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.949 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.955 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:27.960 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.620 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.624 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.628 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.631 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.635 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.639 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.644 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.652 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.658 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.663 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.667 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.758 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.761 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.765 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.769 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.773 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.890 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:29.894 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.167 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.171 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.174 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.178 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.182 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.185 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.189 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.195 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.200 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.205 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.278 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.283 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.287 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.290 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.295 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.407 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.413 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.421 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.427 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.430 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.436 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.531 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:31.538 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:32.727 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:32.732 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:32.736 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:32.741 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:32.746 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:32.752 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:32.756 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:32.759 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:32.762 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.098 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.102 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.107 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.111 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.114 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.118 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.121 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.125 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.128 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.133 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.136 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.768 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.773 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.778 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.781 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.785 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.789 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.794 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.797 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.802 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.805 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.811 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.816 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.916 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:35.921 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:37.211 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:37.214 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:37.219 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:37.223 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:37.228 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:37.232 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:37.235 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:37.239 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:37.242 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:37.289 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:37.294 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:37.297 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:37.302 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:39.874 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:39.877 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:39.879 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:39.883 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:39.886 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:39.890 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:39.894 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:39.913 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:39.917 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:39.920 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:39.923 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:39.925 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:39.928 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:40.027 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:40.031 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:40.035 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:40.038 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:40.042 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:40.132 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:40.136 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:40.142 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:40.146 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:40.151 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.407 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.411 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.414 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.417 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.421 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.423 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.427 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.433 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.436 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.439 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.443 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.448 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.546 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.551 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.555 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.560 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.564 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:42.568 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.675 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.679 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.682 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.685 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.688 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.691 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.695 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.698 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.701 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.705 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.708 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.790 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.793 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.797 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:43.801 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:44.872 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:44.875 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:44.878 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:44.882 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:44.885 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:44.888 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:44.891 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:44.910 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:44.914 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:44.918 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:44.921 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:44.924 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:44.927 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:45.021 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:45.027 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:45.032 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:37:45.035 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# ...
# 23:38:40.982 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:40.987 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:40.989 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:40.992 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:40.996 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:41.002 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:41.006 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:41.009 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:43.014 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:43.017 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:43.020 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:43.024 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:43.028 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:43.031 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:43.033 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:43.046 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:43.050 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:43.054 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:43.059 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:43.063 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:45.033 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:45.036 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:45.040 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:45.043 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:45.048 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:45.052 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:45.056 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:45.060 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:45.062 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:45.068 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:45.070 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:46.089 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:46.092 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:46.096 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:46.099 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:46.102 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:46.108 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:46.114 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:46.119 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:46.122 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:48.425 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:48.428 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:48.432 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:48.436 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:48.439 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:48.442 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:48.445 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:48.449 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:48.453 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:48.502 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:48.507 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:48.510 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:48.514 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:50.609 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:50.612 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:50.615 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:50.619 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:50.622 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:50.625 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:52.583 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:52.586 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:52.589 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:52.592 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:52.596 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:52.601 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:52.607 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:52.610 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:52.613 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:52.616 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:52.619 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:54.739 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:54.745 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:54.751 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:54.757 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:54.762 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:57.029 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:57.035 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:57.040 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:57.045 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:57.050 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:57.058 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:57.063 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:57.090 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:57.093 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:57.098 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
# 23:38:57.105 [main] WARN org.terrier.matching.models.PerFieldNormWeightingModel - Weighting model BM25F is invoked on an index with only 1 field - this is probably incorrect.
#         name       map      ndcg  recip_rank       R@5      R@10      R@15  \
# 5      BM25F  0.119521  0.273847    0.454871  0.093935  0.141545  0.165461
# 0       BM25  0.117823  0.270806    0.434107  0.109873  0.155567  0.174526
# 3    DFRMB25  0.116665  0.268631    0.421853  0.110683  0.154856  0.173304
# 4  DFREEKLIM  0.115480  0.263271    0.435876  0.100247  0.128225  0.147711
# 2        LGD  0.110804  0.253801    0.403710  0.104941  0.130880  0.147912
#
#        R@20      R@30     R@100     R@200     R@500    R@1000          mrt
# 5  0.176549  0.194651  0.252839  0.284266  0.339094  0.386635  1826.932379
# 0  0.184715  0.199172  0.266976  0.298375  0.345242  0.388832    55.537914
# 3  0.187393  0.196851  0.266232  0.298968  0.344494  0.389348    49.073119
# 4  0.163201  0.186658  0.252630  0.289841  0.343033  0.381409    45.158072
# 2  0.168266  0.191016  0.228181  0.274004  0.333968  0.372876    56.949954

# %%
#testing query of best fitting model to go into the UI

index_ref = pt.IndexRef.of('./WebPage/pd_index')
# index_1 = index_ref.loadIndex()

searcher = pt.BatchRetrieve(index_ref, wmodel='DFReeKLIM')

# search for a query
query = "game of thrones"
# proc_query = pre_process(query)
results = searcher.search(query)

results
# Out:
#     qid  docid  docno  rank      score            query
# 0     1  77400  77400     0  19.407843  game of thrones
# 1     1  53201  53201     1  18.830445  game of thrones
# 2     1  39711  39711     2  17.912550  game of thrones
# 3     1  73720  73720     3  17.338374  game of thrones
# 4     1  62913  62913     4  17.260843  game of thrones
# ..   ..    ...    ...   ...        ...              ...
# 995   1  58659  58659   995   5.228509  game of thrones
# 996   1  75639  75639   996   5.228509  game of thrones
# 997   1  77514  77514   997   5.228509  game of thrones
# 998   1  82038  82038   998   5.228509  game of thrones
# 999   1  84661  84661   999   5.228509  game of thrones
#
# [1000 rows x 6 columns]
